# %%
# imports
import pandas as pd
import numpy as np
import category_encoders as ce
from xgboost import XGBClassifier
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
# suppress warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"https://raw.githubusercontent.com/JonathanBechtel/dat-02-22/main/ClassMaterial/Unit3/data/ks2.csv")

# %%
# helper functions to aid in the process
def split_data(df, split_frac=0.2, random_state=42):
    df = df.drop(['deadline', 'launched'], axis = 1)
    X  = df.drop('state', axis=1)
    y  = df['state']
    # notice the use of 'stratify' -- makes sure y values are in equal proportions in train + test
    return train_test_split(X, y, test_size = split_frac, stratify = y, random_state = random_state)

# helper function to pull out feature importances_
def get_feature_importances(pipe, X_train, onehot=False):
    if onehot:
        X_train = pipe[0].transform(X_train)
        X_train = pipe[1].transform(X_train)
    return pd.DataFrame({
        'Col': X_train.columns,
        'Importance': pipe[-1].feature_importances_
    }).sort_values(by='Importance', ascending=False)

# %%
df.state.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
def get_model_scores(mod, X_train, y_train, X_test, y_test, val_score = True, test_score=False):
    if val_score:
        X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                          test_size = 0.2, 
                                                          stratify = y_train, 
                                                          random_state= 42)
 
    mod.fit(X_train, y_train)
    
    results = {}
    
    results['train_score'] = mod.score(X_train, y_train)
    if val_score:
        results['val_score'] = mod.score(X_val, y_val)
        
    if test_score:
        results['test_score'] = mod.score(X_test, y_test)
        
    return results

# %%
# split data
X_train, X_test, y_train, y_test = split_data(df)

# create pipe and get model score
te   = ce.TargetEncoder(min_samples_leaf = 30)
# setting eval_metric here to avoid a warning message -- does not really change anything though
mod  = XGBClassifier(eval_metric = 'logloss')

pipe = make_pipeline(te, mod)

scores = get_model_scores(pipe, X_train, y_train, X_test, y_test, test_score = True)

# initial scores are closely aligned, will leave test set alone for now
scores
# Out:
# {'train_score': 0.6991522206756928,
#  'val_score': 0.6874799655829804,
#  'test_score': 0.6884776828494689}

# %%
train_idx = X_train.index

# %%
train_idx
# Out:
# Int64Index([317618, 181611, 195846,  37117,  95025, 127068,  55623, 312957,
#             223810,  20089,
#             ...
#              92806,  13401,  27823, 178806, 184316, 134725, 106564,  35971,
#               6711, 106672],
#            dtype='int64', length=296363)

# %%
grouping = df.iloc[train_idx].groupby('category')['goal'].mean().reset_index().rename({'goal': 'cat_avg'}, axis = 1)

# %%
grouping
# Out:
#         category        cat_avg
# 0    3D Printing   46466.180661
# 1       Academic   64565.577500
# 2    Accessories   13403.480450
# 3         Action  373074.337457
# 4        Animals   10290.464145
# ..           ...            ...
# 154  Woodworking   11374.694298
# 155    Workshops   10007.921221
# 156  World Music   33424.979016
# 157  Young Adult   24821.152946
# 158        Zines   11407.952804
#
# [159 rows x 2 columns]

# %%
df = df.merge(grouping, on ='category', how = 'left')

# %%
df['cat_pct'] = df['goal'] / df['cat_avg']

# %%
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency             deadline  \
# 0          Poetry    Publishing      GBP  2015-10-09 00:00:00
# 1  Narrative Film  Film & Video      USD  2017-11-01 00:00:00
# 2  Narrative Film  Film & Video      USD  2013-02-26 00:00:00
# 3           Music         Music      USD  2012-04-16 00:00:00
# 4    Film & Video  Film & Video      USD  2015-08-29 00:00:00
#
#               launched  state country      goal       cat_avg   cat_pct
# 0  2015-08-11 12:12:28      0      GB   1533.95   5357.412576  0.286323
# 1  2017-09-02 04:43:57      0      US  30000.00  61956.089277  0.484214
# 2  2013-01-12 00:20:50      0      US  45000.00  61956.089277  0.726321
# 3  2012-03-17 03:24:11      0      US   5000.00  23047.711072  0.216941
# 4  2015-07-04 08:35:03      0      US  19500.00  91834.510688  0.212338

# %%
train_idx
# Out:
# Int64Index([317618, 181611, 195846,  37117,  95025, 127068,  55623, 312957,
#             223810,  20089,
#             ...
#              92806,  13401,  27823, 178806, 184316, 134725, 106564,  35971,
#               6711, 106672],
#            dtype='int64', length=296363)

# %%
df.iloc[train_idx]
# Out:
#                 ID                                               name  \
# 317618   723318017                                   City Reflections
# 181611  1944996418  Nothin' To Lose Entertainment Album & Album Re...
# 195846  2019366381  The Real African History:  As It Relates To Th...
# 37117   1192319792                            Ameritocracy: Card Game
# 95025   1493261104                          $1 + 10K PEOPLE CHALLENGE
# ...            ...                                                ...
# 134725  1699214470  Making a horror movie about finding the Founta...
# 106564  1553430656                                    The Nightingale
# 35971   1186439102                          Double D string stretcher
# 6711    1034862045     Visions of Fantastic Realms - Calendar Project
# 106672  1553980675                      James for PCT: We Go Together
#
#               category main_category currency             deadline  \
# 317618     Photography   Photography      USD  2012-05-31 00:00:00
# 181611         Hip-Hop         Music      USD  2013-08-03 00:00:00
# 195846      Nonfiction    Publishing      USD  2014-09-12 00:00:00
# 37117   Tabletop Games         Games      USD  2016-05-18 00:00:00
# 95025          Hip-Hop         Music      USD  2015-08-11 00:00:00
# ...                ...           ...      ...                  ...
# 134725    Film & Video  Film & Video      USD  2012-09-01 00:00:00
# 106564          Design        Design      DKK  2016-10-24 00:00:00
# 35971            Music         Music      USD  2016-06-23 00:00:00
# 6711      Illustration           Art      USD  2012-01-01 00:00:00
# 106672           Music         Music      USD  2017-05-01 00:00:00
#
#                    launched  state country      goal       cat_avg   cat_pct
# 317618  2012-04-11 15:40:45      0      US    1500.0  10736.366800  0.139712
# 181611  2013-07-04 02:49:02      0      US   10000.0  20588.600707  0.485706
# 195846  2014-07-14 23:45:23      0      US  100000.0  19051.776030  5.248854
# 37117   2016-04-15 18:02:56      1      US   12500.0  14717.959924  0.849302
# 95025   2015-07-12 16:24:52      0      US   10000.0  20588.600707  0.485706
# ...                     ...    ...     ...       ...           ...       ...
# 134725  2012-08-18 00:02:14      1      US    3300.0  91834.510688  0.035934
# 106564  2016-09-29 08:24:23      0      DK   36709.1  30123.085015  1.218637
# 35971   2016-05-14 17:12:57      0      US   25000.0  23047.711072  1.084706
# 6711    2011-12-14 03:40:58      0      US    5000.0  35343.614746  0.141468
# 106672  2017-04-01 20:44:59      1      US    5000.0  23047.711072  0.216941
#
# [296363 rows x 12 columns]

# %%
country_grouping = df.iloc[train_idx].groupby('country')['goal'].mean().reset_index().rename({'goal': 'cntry_avg'}, axis = 1)

# %%
df = df.merge(country_grouping, on ='country', how = 'left')

# %%
df['cntry_pct'] = df['goal'] / df['cntry_avg']

# %%
# split data
X_train, X_test, y_train, y_test = split_data(df)

# create pipe and get model score
te   = ce.TargetEncoder(min_samples_leaf = 30)
# setting eval_metric here to avoid a warning message -- does not really change anything though
mod  = XGBClassifier(eval_metric = 'logloss')

pipe = make_pipeline(te, mod)

scores = get_model_scores(pipe, X_train, y_train, X_test, y_test)

# initial scores are closely aligned, will leave test set alone for now
scores
# Out:
# {'train_score': 0.7010755409338226, 'val_score': 0.6885934573920672}

# %%
X_train
# Out:
#                 ID                                               name  \
# 317618   723318017                                   City Reflections
# 181611  1944996418  Nothin' To Lose Entertainment Album & Album Re...
# 195846  2019366381  The Real African History:  As It Relates To Th...
# 37117   1192319792                            Ameritocracy: Card Game
# 95025   1493261104                          $1 + 10K PEOPLE CHALLENGE
# ...            ...                                                ...
# 134725  1699214470  Making a horror movie about finding the Founta...
# 106564  1553430656                                    The Nightingale
# 35971   1186439102                          Double D string stretcher
# 6711    1034862045     Visions of Fantastic Realms - Calendar Project
# 106672  1553980675                      James for PCT: We Go Together
#
#               category main_category currency country      goal       cat_avg  \
# 317618     Photography   Photography      USD      US    1500.0  10736.366800
# 181611         Hip-Hop         Music      USD      US   10000.0  20588.600707
# 195846      Nonfiction    Publishing      USD      US  100000.0  19051.776030
# 37117   Tabletop Games         Games      USD      US   12500.0  14717.959924
# 95025          Hip-Hop         Music      USD      US   10000.0  20588.600707
# ...                ...           ...      ...     ...       ...           ...
# 134725    Film & Video  Film & Video      USD      US    3300.0  91834.510688
# 106564          Design        Design      DKK      DK   36709.1  30123.085015
# 35971            Music         Music      USD      US   25000.0  23047.711072
# 6711      Illustration           Art      USD      US    5000.0  35343.614746
# 106672           Music         Music      USD      US    5000.0  23047.711072
#
#          cat_pct     cntry_avg  cntry_pct
# 317618  0.139712  42877.290333   0.034984
# 181611  0.485706  42877.290333   0.233224
# 195846  5.248854  42877.290333   2.332237
# 37117   0.849302  42877.290333   0.291530
# 95025   0.485706  42877.290333   0.233224
# ...          ...           ...        ...
# 134725  0.035934  42877.290333   0.076964
# 106564  1.218637  25087.408737   1.463248
# 35971   1.084706  42877.290333   0.583059
# 6711    0.141468  42877.290333   0.116612
# 106672  0.216941  42877.290333   0.116612
#
# [296363 rows x 11 columns]

# %%
# parameter search
estimators = [100, 200, 300, 400]
max_depth  = [3, 4]
sub_sample = [0.8, 0.6] # this is the amount of samples to randomly sample in each round
learning_rate = [0.1, 0.2]
cv_scores  = []

# do a training loop
for estimator in estimators:
    for depth in max_depth:
        for sample in sub_sample:
            for rate in learning_rate:
                print(f"Fitting new training loop for rounds: {estimator}, depth: {depth}, sampling rate: {sample}, rate: {rate}")
                pipe[-1].set_params(n_estimators = estimator, 
                                    max_depth = depth, 
                                    subsample = sample,
                                    learning_rate = rate)
                scores = get_model_scores(pipe, X_train, y_train, X_test, y_test)
                cv_scores.append((scores['train_score'], scores['val_score'], estimator, depth, sample, rate))
# Out:
# Fitting new training loop for rounds: 100, depth: 3, sampling rate: 0.8, rate: 0.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-1fcf3143d8c1> in <module>
#      16                                     subsample = sample,
#      17                                     learning_rate = rate)
# ---> 18                 scores = get_model_scores(pipe, X_train, y_train, X_test, y_test)
#      19                 cv_scores.append((scores['train_score'], scores['val_score'], estimator, depth, sample, rate))
#
# <ipython-input-5-3f34ff6b07d4> in get_model_scores(mod, X_train, y_train, X_test, y_test, val_score, test_score)
#       6                                                           random_state= 42)
#       7
# ----> 8     mod.fit(X_train, y_train)
#       9
#      10     results = {}
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     339         """
#     340         fit_params_steps = self._check_fit_params(**fit_params)
# --> 341         Xt = self._fit(X, y, **fit_params_steps)
#     342         with _print_elapsed_time('Pipeline',
#     343                                  self._log_message(len(self.steps) - 1)):
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params_steps)
#     301                 cloned_transformer = clone(transformer)
#     302             # Fit or load from cache the current transformer
# --> 303             X, fitted_transformer = fit_transform_one_cached(
#     304                 cloned_transformer, X, y, None,
#     305                 message_clsname='Pipeline',
#
# ~\anaconda3\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     350
#     351     def __call__(self, *args, **kwargs):
# --> 352         return self.func(*args, **kwargs)
#     353
#     354     def call_and_shelve(self, *args, **kwargs):
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     752     with _print_elapsed_time(message_clsname, message):
#     753         if hasattr(transformer, 'fit_transform'):
# --> 754             res = transformer.fit_transform(X, y, **fit_params)
#     755         else:
#     756             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~\anaconda3\lib\site-packages\category_encoders\utils.py in fit_transform(self, X, y, **fit_params)
#     148         if y is None:
#     149             raise TypeError('fit_transform() missing argument: ''y''')
# --> 150         return self.fit(X, y, **fit_params).transform(X, y)
#
# ~\anaconda3\lib\site-packages\category_encoders\target_encoder.py in fit(self, X, y, **kwargs)
#     140             handle_missing='value'
#     141         )
# --> 142         self.ordinal_encoder = self.ordinal_encoder.fit(X)
#     143         X_ordinal = self.ordinal_encoder.transform(X)
#     144         self.mapping = self.fit_target_encoding(X_ordinal, y)
#
# ~\anaconda3\lib\site-packages\category_encoders\ordinal.py in fit(self, X, y, **kwargs)
#     137                 raise ValueError('Columns to be encoded can not contain null')
#     138
# --> 139         _, categories = self.ordinal_encoding(
#     140             X,
#     141             mapping=self.mapping,
#
# ~\anaconda3\lib\site-packages\category_encoders\ordinal.py in ordinal_encoding(X_in, mapping, cols, handle_unknown, handle_missing)
#     329                         categories += [np.nan]
#     330
# --> 331                 index = pd.Series(categories).fillna(nan_identity).unique()
#     332
#     333                 data = pd.Series(index=index, data=range(1, len(index) + 1))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     362                     data = data.copy()
#     363             else:
# --> 364                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     365
#     366                 data = SingleBlockManager.from_array(data, index)
#
# ~\anaconda3\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     480             subarr = _try_cast(data, dtype, copy, raise_cast_failure)
#     481         else:
# --> 482             subarr = maybe_convert_platform(data)
#     483
#     484         subarr = maybe_cast_to_datetime(subarr, dtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in maybe_convert_platform(values)
#     110     """ try to do platform conversion, allow ndarray or list here """
#     111     if isinstance(values, (list, tuple, range)):
# --> 112         values = construct_1d_object_array_from_listlike(values)
#     113     if getattr(values, "dtype", None) == np.object_:
#     114         if hasattr(values, "_values"):
#
# KeyboardInterrupt:

# %%
max(cv_scores, key = lambda x: x[1])
# Out:
# (0.6889493441309208, 0.6883066488957873, 100, 4, 0.6, 0.1)

# %%
ohe = ce.OneHotEncoder(cols = ['category', 'country', 'currency'], use_cat_names = True)
te  = ce.TargetEncoder()

pipe = make_pipeline(ohe, te, mod)

# %%
pipe[-1].set_params(n_estimators = 300, max_depth = 4, sub_sample = 0.8, learning_rate = 0.1)
# Out:
# [20:12:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric='logloss', gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=4, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=300, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, sub_sample=0.8,
#               subsample=0.6, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
X_train
# Out:
#                 ID                                               name  \
# 317618   723318017                                   City Reflections
# 181611  1944996418  Nothin' To Lose Entertainment Album & Album Re...
# 195846  2019366381  The Real African History:  As It Relates To Th...
# 37117   1192319792                            Ameritocracy: Card Game
# 95025   1493261104                          $1 + 10K PEOPLE CHALLENGE
# ...            ...                                                ...
# 134725  1699214470  Making a horror movie about finding the Founta...
# 106564  1553430656                                    The Nightingale
# 35971   1186439102                          Double D string stretcher
# 6711    1034862045     Visions of Fantastic Realms - Calendar Project
# 106672  1553980675                      James for PCT: We Go Together
#
#               category main_category currency country      goal       cat_avg  \
# 317618     Photography   Photography      USD      US    1500.0  10736.366800
# 181611         Hip-Hop         Music      USD      US   10000.0  20588.600707
# 195846      Nonfiction    Publishing      USD      US  100000.0  19051.776030
# 37117   Tabletop Games         Games      USD      US   12500.0  14717.959924
# 95025          Hip-Hop         Music      USD      US   10000.0  20588.600707
# ...                ...           ...      ...     ...       ...           ...
# 134725    Film & Video  Film & Video      USD      US    3300.0  91834.510688
# 106564          Design        Design      DKK      DK   36709.1  30123.085015
# 35971            Music         Music      USD      US   25000.0  23047.711072
# 6711      Illustration           Art      USD      US    5000.0  35343.614746
# 106672           Music         Music      USD      US    5000.0  23047.711072
#
#          cat_pct     cntry_avg  cntry_pct
# 317618  0.139712  42877.290333   0.034984
# 181611  0.485706  42877.290333   0.233224
# 195846  5.248854  42877.290333   2.332237
# 37117   0.849302  42877.290333   0.291530
# 95025   0.485706  42877.290333   0.233224
# ...          ...           ...        ...
# 134725  0.035934  42877.290333   0.076964
# 106564  1.218637  25087.408737   1.463248
# 35971   1.084706  42877.290333   0.583059
# 6711    0.141468  42877.290333   0.116612
# 106672  0.216941  42877.290333   0.116612
#
# [296363 rows x 11 columns]

# %%
X_train
# Out:
#                 ID                                               name  \
# 317618   723318017                                   City Reflections
# 181611  1944996418  Nothin' To Lose Entertainment Album & Album Re...
# 195846  2019366381  The Real African History:  As It Relates To Th...
# 37117   1192319792                            Ameritocracy: Card Game
# 95025   1493261104                          $1 + 10K PEOPLE CHALLENGE
# ...            ...                                                ...
# 134725  1699214470  Making a horror movie about finding the Founta...
# 106564  1553430656                                    The Nightingale
# 35971   1186439102                          Double D string stretcher
# 6711    1034862045     Visions of Fantastic Realms - Calendar Project
# 106672  1553980675                      James for PCT: We Go Together
#
#               category main_category currency country      goal       cat_avg  \
# 317618     Photography   Photography      USD      US    1500.0  10736.366800
# 181611         Hip-Hop         Music      USD      US   10000.0  20588.600707
# 195846      Nonfiction    Publishing      USD      US  100000.0  19051.776030
# 37117   Tabletop Games         Games      USD      US   12500.0  14717.959924
# 95025          Hip-Hop         Music      USD      US   10000.0  20588.600707
# ...                ...           ...      ...     ...       ...           ...
# 134725    Film & Video  Film & Video      USD      US    3300.0  91834.510688
# 106564          Design        Design      DKK      DK   36709.1  30123.085015
# 35971            Music         Music      USD      US   25000.0  23047.711072
# 6711      Illustration           Art      USD      US    5000.0  35343.614746
# 106672           Music         Music      USD      US    5000.0  23047.711072
#
#          cat_pct     cntry_avg  cntry_pct
# 317618  0.139712  42877.290333   0.034984
# 181611  0.485706  42877.290333   0.233224
# 195846  5.248854  42877.290333   2.332237
# 37117   0.849302  42877.290333   0.291530
# 95025   0.485706  42877.290333   0.233224
# ...          ...           ...        ...
# 134725  0.035934  42877.290333   0.076964
# 106564  1.218637  25087.408737   1.463248
# 35971   1.084706  42877.290333   0.583059
# 6711    0.141468  42877.290333   0.116612
# 106672  0.216941  42877.290333   0.116612
#
# [296363 rows x 11 columns]

# %%
# split data
X_train, X_test, y_train, y_test = split_data(df)

# %%
feats = get_feature_importances(pipe, X_train)

# %%
feats
# Out:
#               Col  Importance
# 2        category    0.464748
# 6            goal    0.212315
# 5         country    0.092606
# 8         cat_pct    0.057861
# 4        currency    0.044849
# 3   main_category    0.033881
# 10      cntry_pct    0.029558
# 9       cntry_avg    0.024191
# 7         cat_avg    0.023552
# 0              ID    0.016439
# 1            name    0.000000

# %%
pipe.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-8fdeddbf88d9> in <module>
# ----> 1 pipe.predict(X_train)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     118
#     119         # lambda, but not partial, allows help() to work with update_wrapper
# --> 120         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     121         # update the docstring of the returned function
#     122         update_wrapper(out, self.fn)
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in predict(self, X, **predict_params)
#     416         Xt = X
#     417         for _, name, transform in self._iter(with_final=False):
# --> 418             Xt = transform.transform(Xt)
#     419         return self.steps[-1][-1].predict(Xt, **predict_params)
#     420
#
# ~\anaconda3\lib\site-packages\category_encoders\one_hot.py in transform(self, X, override_return_df)
#     244
#     245         if self._dim is None:
# --> 246             raise ValueError(
#     247                 'Must train encoder before it can be used to transform data.')
#     248
#
# ValueError: Must train encoder before it can be used to transform data.

# %%
pipe.predict_proba(X_train)

# %%
from pdpbox import pdp, info_plots

# go ahead and transform X_train to prep it for PDPBox
# the model is already fitted so we don't have to worry about doing that
X_train = pipe[0].transform(X_train)

# %%
dir(pdp_day_of_week)

# %%
# what was the additive impact of different values of goal?  What was its marginal impact?
pdp_day_of_week = pdp.pdp_isolate(
    model=pipe[-1], 
    dataset=X_train[X_train['goal'] < X_train['goal'].quantile(.95)], # filtering out unusually large values
    model_features=X_train.columns.tolist(), 
    feature='goal',
)

fig, axes = pdp.pdp_plot(pdp_day_of_week, 'Fundraising Amount', plot_lines=True, frac_to_plot=100)
