# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeRegressor
import category_encoders as ce

# %%
df = pd.read_csv('/Users/liamsweeney/dat-11-15/Homework/Unit2/data/master.csv')

# %%
df
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24  2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24  2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24  2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24  2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24  2016-01-18         6    2016-01-18      Monday
# ...                      ...         ...       ...           ...         ...
# 252103  air_a17f0778617c76e2  2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2  2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2  2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2  2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2  2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
df.isnull().sum()
# Out:
# id                       0
# visit_date               0
# visitors                 0
# calendar_date            0
# day_of_week              0
# holiday                  0
# genre                    0
# area                     0
# latitude                 0
# longitude                0
# reserve_visitors    143714
# dtype: int64

# %%
df['reserve_visitors'].value_counts().sort_index()
# Out:
# 1.0      1975
# 2.0     13587
# 3.0      5376
# 4.0      8042
# 5.0      3581
# 6.0      4627
# 7.0      6713
# 8.0      5639
# 9.0      3738
# 10.0     6703
# 11.0     2439
# 12.0     3677
# 13.0      744
# 14.0     1318
# 15.0     2259
# 16.0      704
# 17.0     1459
# 18.0     1047
# 20.0      722
# 21.0     2591
# 22.0      696
# 23.0     3564
# 24.0      613
# 25.0     3476
# 27.0      736
# 28.0      706
# 30.0     1297
# 31.0      738
# 32.0     1182
# 33.0      771
# 35.0     1358
# 36.0     2033
# 37.0      774
# 40.0      731
# 41.0      772
# 42.0      608
# 43.0     1372
# 44.0     1246
# 46.0     1393
# 47.0      771
# 48.0      603
# 51.0      659
# 54.0      767
# 58.0      574
# 59.0      672
# 60.0     1411
# 76.0      767
# 83.0      575
# 96.0      588
# Name: reserve_visitors, dtype: int64

# %%
df['reserve_visitors_na'] = df['reserve_visitors'].isnull()

# %%
df['reserve_visitors'] = df['reserve_visitors'].fillna(0)

# %%
df.head()
# Out:
#                      id  visit_date  visitors calendar_date day_of_week  \
# 0  air_ba937bf13d40fb24  2016-01-13        25    2016-01-13   Wednesday
# 1  air_ba937bf13d40fb24  2016-01-14        32    2016-01-14    Thursday
# 2  air_ba937bf13d40fb24  2016-01-15        29    2016-01-15      Friday
# 3  air_ba937bf13d40fb24  2016-01-16        22    2016-01-16    Saturday
# 4  air_ba937bf13d40fb24  2016-01-18         6    2016-01-18      Monday
#
#    holiday       genre                          area   latitude   longitude  \
# 0        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 1        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 2        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 3        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 4        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
#
#    reserve_visitors  reserve_visitors_na
# ...

# %%
transformed = df.groupby(['day_of_week', 'area'])['reserve_visitors'].transform('mean')

# %%
df['reserve_visitors'] = df['reserve_visitors'].fillna(transformed.astype(int))

# %%
df
# Out:
#                           id  visit_date  visitors calendar_date day_of_week  \
# 0       air_ba937bf13d40fb24  2016-01-13        25    2016-01-13   Wednesday
# 1       air_ba937bf13d40fb24  2016-01-14        32    2016-01-14    Thursday
# 2       air_ba937bf13d40fb24  2016-01-15        29    2016-01-15      Friday
# 3       air_ba937bf13d40fb24  2016-01-16        22    2016-01-16    Saturday
# 4       air_ba937bf13d40fb24  2016-01-18         6    2016-01-18      Monday
# ...                      ...         ...       ...           ...         ...
# 252103  air_a17f0778617c76e2  2017-04-21        49    2017-04-21      Friday
# 252104  air_a17f0778617c76e2  2017-04-22        60    2017-04-22    Saturday
# 252105  air_a17f0778617c76e2  2017-03-26        69    2017-03-26      Sunday
# 252106  air_a17f0778617c76e2  2017-03-20        31    2017-03-20      Monday
# 252107  air_a17f0778617c76e2  2017-04-09        26    2017-04-09      Sunday
#
# ...

# %%
query = df['reserve_visitors'].isnull()

# %%
train = df.loc[~query, :]
test = df.loc[query, :]

# %%
train.head()
# Out:
#                       id  visit_date  visitors calendar_date day_of_week  \
# 11  air_ba937bf13d40fb24  2016-01-26        11    2016-01-26     Tuesday
# 21  air_ba937bf13d40fb24  2016-02-09        15    2016-02-09     Tuesday
# 24  air_ba937bf13d40fb24  2016-02-12        26    2016-02-12      Friday
# 25  air_ba937bf13d40fb24  2016-02-13         8    2016-02-13    Saturday
# 37  air_ba937bf13d40fb24  2016-02-27        23    2016-02-27    Saturday
#
#     holiday       genre                          area   latitude   longitude  \
# 11        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 21        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 24        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 25        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 37        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
#
#     reserve_visitors
# 11               2.0
# ...

# %%
test.head()
# Out:
#                      id  visit_date  visitors calendar_date day_of_week  \
# 0  air_ba937bf13d40fb24  2016-01-13        25    2016-01-13   Wednesday
# 1  air_ba937bf13d40fb24  2016-01-14        32    2016-01-14    Thursday
# 2  air_ba937bf13d40fb24  2016-01-15        29    2016-01-15      Friday
# 3  air_ba937bf13d40fb24  2016-01-16        22    2016-01-16    Saturday
# 4  air_ba937bf13d40fb24  2016-01-18         6    2016-01-18      Monday
#
#    holiday       genre                          area   latitude   longitude  \
# 0        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 1        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 2        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 3        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 4        0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
#
#    reserve_visitors
# 0               NaN
# 1               NaN
# ...

# %%
tree = DecisionTreeRegressor(max_depth = 3)

# %%
X = train.select_dtypes(include = np.number).drop('reserve_visitors', axis = 1)
y = train['reserve_visitors']

tree.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
df['reserve_visitors'] = df['reserve_visitors'].fillna(tree.predict(test.select_dtypes(include = np.number).drop('reserve_visitors', axis = 1)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-b978de135d95> in <module>
# ----> 1 df['reserve_visitors'] = df['reserve_visitors'].fillna(tree.predict(test.select_dtypes(include = np.number).drop('reserve_visitors', axis = 1)))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    4461         downcast=None,
#    4462     ) -> Optional["Series"]:
# -> 4463         return super().fillna(
#    4464             value=value,
#    4465             method=method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    6400                     pass
#    6401                 else:
# -> 6402                     raise TypeError(
# ...
